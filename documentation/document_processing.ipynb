# %%
import os
image_extensions = ('.jpg', '.jpeg', '.png', '.gif', '.bmp', '.tiff', '.webp', '.svg', '.ico')
for root, dirs, files in os.walk(os.curdir):
        for file in files:
            if file.lower().endswith(image_extensions):
                file_path = os.path.join(root, file)
                os.remove(file_path)
                print(f"Deleted: {file_path}")
# Out:
# Deleted: ./docs-code/themes/ace-documentation/images/screenshot.png
# Deleted: ./docs-code/themes/ace-documentation/images/tn.png
# Deleted: ./docs-code/themes/ace-documentation/static/webfonts/fa-brands-400.svg
# Deleted: ./docs-code/themes/ace-documentation/static/webfonts/fa-regular-400.svg
# Deleted: ./docs-code/themes/ace-documentation/static/webfonts/fa-solid-900.svg
# Deleted: ./docs-code/static/interactive-map.png
# Deleted: ./docs-code/static/slicer-overview.png
# Deleted: ./docs-code/static/developer.svg
# Deleted: ./docs-code/static/UCY.jpg
# Deleted: ./docs-code/static/mobility-eval.png
# Deleted: ./docs-code/static/AUTH.jpg
# Deleted: ./docs-code/static/rainbow_logo.png
# Deleted: ./docs-code/static/bestdemo.png
# Deleted: ./docs-code/static/plots.jpg
# Deleted: ./docs-code/static/fogify-overview.png
# Deleted: ./docs-code/static/researcher.svg
# Deleted: ./docs-code/static/model.png
# Deleted: ./docs-code/static/overview.jpg
# Deleted: ./docs-code/static/5gslicer-UI.png
# Deleted: ./docs-code/static/jupyter.png
# Deleted: ./docs-code/static/jupyter-GUI.png
# Deleted: ./docs-code/static/UNIC.jpg
# Deleted: ./docs-code/static/infra.svg
# Deleted: ./docs-code/static/results/application.png
# Deleted: ./docs-code/static/results/processing.png
# Deleted: ./docs-code/static/results/network.png
# Deleted: ./docs-code/static/get-started-images/undeploy.png
# Deleted: ./docs-code/static/get-started-images/IDE.png
# Deleted: ./docs-code/static/get-started-images/finish_deployment.png
# Deleted: ./docs-code/static/get-started-images/scenario-plot.png
# Deleted: ./docs-code/static/get-started-images/starting_deployment.png
# Deleted: ./docs-code/static/get-started-images/metrics.png
# Deleted: ./docs-code/static/get-started-images/metrics-2.png
# Deleted: ./docs-code/static/get-started-images/scenario-execution.png
# Deleted: ./docs-code/static/get-started-images/metrics-3.png
# Deleted: ./docs/interactive-map.png
# Deleted: ./docs/slicer-overview.png
# Deleted: ./docs/developer.svg
# Deleted: ./docs/UCY.jpg
# Deleted: ./docs/mobility-eval.png
# Deleted: ./docs/AUTH.jpg
# Deleted: ./docs/rainbow_logo.png
# Deleted: ./docs/bestdemo.png
# Deleted: ./docs/plots.jpg
# Deleted: ./docs/fogify-overview.png
# Deleted: ./docs/researcher.svg
# Deleted: ./docs/model.png
# Deleted: ./docs/overview.jpg
# Deleted: ./docs/5gslicer-UI.png
# Deleted: ./docs/jupyter.png
# Deleted: ./docs/jupyter-GUI.png
# Deleted: ./docs/UNIC.jpg
# Deleted: ./docs/infra.svg
# Deleted: ./docs/webfonts/fa-brands-400.svg
# Deleted: ./docs/webfonts/fa-regular-400.svg
# Deleted: ./docs/webfonts/fa-solid-900.svg
# Deleted: ./docs/results/application.png
# Deleted: ./docs/results/processing.png
# Deleted: ./docs/results/network.png
# Deleted: ./docs/get-started-images/undeploy.png
# Deleted: ./docs/get-started-images/IDE.png
# Deleted: ./docs/get-started-images/finish_deployment.png
# Deleted: ./docs/get-started-images/scenario-plot.png
# Deleted: ./docs/get-started-images/starting_deployment.png
# Deleted: ./docs/get-started-images/metrics.png
# Deleted: ./docs/get-started-images/metrics-2.png
# Deleted: ./docs/get-started-images/scenario-execution.png
# Deleted: ./docs/get-started-images/metrics-3.png
# Deleted: ./examples/taxi-demo/images/UCY.jpg
# Deleted: ./examples/taxi-demo/images/AUTH.jpg
# Deleted: ./examples/taxi-demo/images/rainbow_logo.png
# Deleted: ./examples/taxi-demo/images/bestdemo.png
# Deleted: ./examples/taxi-demo/images/jupyter.png
# Deleted: ./examples/taxi-demo/images/UNIC.jpg
# Deleted: ./examples/taxi-demo/images/results/application.png
# Deleted: ./examples/taxi-demo/images/results/processing.png
# Deleted: ./examples/taxi-demo/images/results/network.png
